# %% [markdown]
# # 1. Überblick über den Datensatz
#
# Dieser Datensatz enthält die Finanzleistungsdaten der 12 größten Unternehmen in Deutschland zwischen 2017 und 2024. Der Datensatz umfasst insgesamt 384 Beobachtungen und 11 Spalten, wobei jede Zeile die Finanzabschlüsse eines bestimmten Unternehmens für ein bestimmtes Quartal oder Geschäftsjahresende darstellt.
#
# **Die im Datensatz enthaltenen Unternehmen sind wie folgt:**
#
# - **Automobilsektor:** Volkswagen AG, BMW AG, Daimler AG, Porsche AG
# - **Technologie und Software:** Siemens AG, SAP SE
# - **Chemie und Pharma:** BASF SE, Bayer AG, Merck KGaA
# - **Finanzen:** Allianz SE, Deutsche Bank AG
# - **Telekommunikation:** Deutsche Telekom AG
#
# **Die Bedeutungen der 11 Spalten im Datensatz sind wie folgt:**
#
# <table style='text-align: left; margin-left: 0;'>
#   <tr>
#     <th>Spaltenname</th>
#     <th>Beschreibung</th>
#   </tr>
#   <tr>
#     <td><strong>Company</strong></td>
#     <td>Name des Unternehmens</td>
#   </tr>
#   <tr>
#     <td><strong>Period</strong></td>
#     <td>Berichtszeitraum des Finanzabschlusses</td>
#   </tr>
#   <tr>
#     <td><strong>Revenue</strong></td>
#     <td>Gesamtumsatz im Berichtszeitraum (EUR)</td>
#   </tr>
#   <tr>
#     <td><strong>Net Income</strong></td>
#     <td>Nettogewinn nach Steuern und allen Aufwendungen (EUR)</td>
#   </tr>
#   <tr>
#     <td><strong>Liabilities</strong></td>
#     <td>Gesamtverbindlichkeiten und Verpflichtungen (EUR)</td>
#   </tr>
#   <tr>
#     <td><strong>Assets</strong></td>
#     <td>Gesamtvermögen des Unternehmens (EUR)</td>
#   </tr>
#   <tr>
#     <td><strong>Equity</strong></td>
#     <td>Eigenkapital (EUR)</td>
#   </tr>
#   <tr>
#     <td><strong>Roa (%)</strong></td>
#     <td>Gesamtkapitalrendite</td>
#   </tr>
#   <tr>
#     <td><strong>Roe (%)</strong></td>
#     <td>Eigenkapitalrendite</td>
#   </tr>
#   <tr>
#     <td><strong>Debt to Equity</strong></td>
#     <td>Verschuldungsgrad</td>
#   </tr>
#   <tr>
#     <td><strong>Percentage Debt to Equity</strong></td>
#     <td>Verschuldungsgrad in Prozent</td>
#   </tr>
# </table>

# %% [markdown]
# # 2. Importieren von Bibliotheken

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
pd.set_option('display.max_columns', None)  
plt.rcParams['figure.figsize'] = (10, 6)  
plt.style.use('ggplot')  
warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Laden des Datensatzes

# %%
df = pd.read_csv('../data/top_12_german_companies_raw.csv')

df
# Out:
#               Company      Period      Revenue    Net Income  Liabilities  \
# 0       Volkswagen AG  12/31/2017   9750496618  5.168898e+08  21354201295
# 1          Siemens AG  12/31/2017  19716237464  1.276840e+09  45009303223
# 2          Allianz SE  12/31/2017  19458831198  1.600107e+09  48538978480
# 3              BMW AG  12/31/2017  18808147150  9.601843e+08  35382107627
# 4             BASF SE  12/31/2017  16895580815  1.797082e+09  28309420014
# ..                ...         ...          ...           ...          ...
# 379            SAP SE   9/30/2024  10824151396  8.302800e+08  42369695133
# 380          Bayer AG   9/30/2024   9332023907  7.466675e+08  23673143006
# 381  Deutsche Bank AG   9/30/2024  18549946525  2.323022e+09  49199711543
# 382        Porsche AG   9/30/2024  15911174550  1.241694e+09  36125130235
# 383        Merck KGaA   9/30/2024  15036344926  1.704098e+09  30603212259
#
#           Assets       Equity        ROA (%)        ROE (%) Debt to Equity  \
# ...

# %%
df_copy = df.copy()

# %% [markdown]
# # 4. Überblick über den Datensatz

# %%
df.sample()
# Out:
#         Company     Period      Revenue    Net Income  Liabilities  \
# 206  Allianz SE  6/30/2018  11661846976  1.354193e+09  23626577882
#
#           Assets       Equity      ROA (%)        ROE (%) Debt to Equity  \
# 206  54731462963  31104885082  247.424.897  4.353.633.376    759.577.726
#
#     percentage  Debt to Equity
# 206                    573,16%

# %%
df.head()
# Out:
#          Company      Period      Revenue    Net Income  Liabilities  \
# 0  Volkswagen AG  12/31/2017   9750496618  5.168898e+08  21354201295
# 1     Siemens AG  12/31/2017  19716237464  1.276840e+09  45009303223
# 2     Allianz SE  12/31/2017  19458831198  1.600107e+09  48538978480
# 3         BMW AG  12/31/2017  18808147150  9.601843e+08  35382107627
# 4        BASF SE  12/31/2017  16895580815  1.797082e+09  28309420014
#
#         Assets       Equity        ROA (%)        ROE (%) Debt to Equity  \
# 0  54861302788  33507101493    942.175.618  1.542.627.668    637.303.746
# 1  75268101508  30258798286  1.696.389.282  4.219.731.382  1.487.478.214
# 2  69583711255  21044732775  2.299.542.624  7.603.361.452  2.306.466.848
# 3  67327482638  31945375011    142.614.028  3.005.706.927  1.107.581.539
# 4  68036567115  39727147101  2.641.347.127  4.523.561.449     71.259.635
#
#   percentage  Debt to Equity
# 0                      0,00%
# 1                    283,68%
# ...

# %%
df.tail()
# Out:
#               Company     Period      Revenue    Net Income  Liabilities  \
# 379            SAP SE  9/30/2024  10824151396  8.302800e+08  42369695133
# 380          Bayer AG  9/30/2024   9332023907  7.466675e+08  23673143006
# 381  Deutsche Bank AG  9/30/2024  18549946525  2.323022e+09  49199711543
# 382        Porsche AG  9/30/2024  15911174550  1.241694e+09  36125130235
# 383        Merck KGaA  9/30/2024  15036344926  1.704098e+09  30603212259
#
#           Assets       Equity        ROA (%)        ROE (%) Debt to Equity  \
# 379  72342104340  29972409208    114.771.336  2.770.147.673  1.413.623.271
# 380  42677324477  19004181470  1.749.565.031  3.928.964.508  1.245.680.749
# 381  64461554635  15261843092  3.603.732.773  1.522.111.161  3.223.707.074
# 382  84583217359  48458087124  1.468.014.459  2.562.407.917    745.492.288
# 383  59444780752  28841568494  2.866.690.036  5.908.477.575  1.061.080.026
#
#     percentage  Debt to Equity
# 379                      0,00%
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Period', 'Revenue', 'Net Income', 'Liabilities', 'Assets',
#        'Equity', 'ROA (%)', 'ROE (%)', 'Debt to Equity',
#        'percentage  Debt to Equity'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     384 non-null    object
#  1   Period                      384 non-null    object
#  2   Revenue                     384 non-null    int64
#  3   Net Income                  384 non-null    float64
#  4   Liabilities                 384 non-null    int64
#  5   Assets                      384 non-null    int64
#  6   Equity                      384 non-null    int64
#  7   ROA (%)                     384 non-null    object
#  8   ROE (%)                     384 non-null    object
#  9   Debt to Equity              384 non-null    object
#  10  percentage  Debt to Equity  384 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 33.1+ KB

# %%
df.describe()
# Out:
#             Revenue    Net Income   Liabilities        Assets        Equity
# count  3.840000e+02  3.840000e+02  3.840000e+02  3.840000e+02  3.840000e+02
# mean   1.270992e+10  1.249025e+09  3.115579e+10  6.141624e+10  3.026045e+10
# std    4.095183e+09  5.445441e+08  1.139538e+10  1.698922e+10  1.172803e+10
# min    5.149850e+09  2.980309e+08  1.004637e+10  2.177324e+10  1.001762e+10
# 25%    9.315161e+09  8.643813e+08  2.085174e+10  5.074013e+10  1.966813e+10
# 50%    1.266963e+10  1.145476e+09  3.230659e+10  6.020715e+10  2.999063e+10
# 75%    1.621724e+10  1.560234e+09  4.088942e+10  7.369075e+10  3.984646e+10
# max    1.990964e+10  2.884007e+09  4.976940e+10  9.657402e+10  4.991812e+10

# %% [markdown]
# <div style='background-color: #ffebee; border-left: 5px solid #f44336; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #c62828;'>🧾 Ergebnisse</h3>
#   <ul>
#     <li>Der Datensatz enthält nicht standardisierte Spaltenbezeichnungen, die während des Analyseprozesses zu Inkonsistenzen führen können.</li>
#     <li>Bei einigen Spalten wurden ungeeignete Datentypen für die analytische Verarbeitung festgestellt.</li>
#     <li>In bestimmten Spaltenwerten wurden Skalierungsprobleme identifiziert.</li>
#   </ul>
# </div>
#
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Entscheidung</h3>
#   <ul>
#     <li>Zur Behebung dieser Probleme werden zunächst die Spaltennamen standardisiert. Anschließend wird eine spaltenbasierte Analyse durchgeführt, um die identifizierten Probleme zu lösen, gefolgt von einer umfassenden explorativen Datenanalyse.</li>
#   </ul>
# </div>

# %% [markdown]
# # 5. Datenbereinigung und Vorverarbeitung

# %%
df.columns = ['company', 'period', 'revenue', 'net_income', 'liabilities', 'assets', 'equity', 'roa', 'roe', 'debt_to_equity', 'percentage_debt_to_equity']

df.columns
# Out:
# Index(['company', 'period', 'revenue', 'net_income', 'liabilities', 'assets',
#        'equity', 'roa', 'roe', 'debt_to_equity', 'percentage_debt_to_equity'],
#       dtype='object')

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Durchgeführte Maßnahme</h3>
#   <ul>
#     <li>Die Spaltennamen wurden in ein standardisiertes Format überführt, um die Lesbarkeit zu verbessern und die Konsistenz im gesamten Analyseprozess sicherzustellen.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.1. Company

# %%
df[['company']].sample(5)
# Out:
#                  company
# 13            Siemens AG
# 202           Porsche AG
# 53   Deutsche Telekom AG
# 240        Volkswagen AG
# 98            Allianz SE

# %%
df.company.dtype
# Out:
# dtype('O')

# %%
df.company.unique()
# Out:
# array(['Volkswagen AG', 'Siemens AG', 'Allianz SE', 'BMW AG', 'BASF SE',
#        'Deutsche Telekom AG', 'Daimler AG', 'SAP SE', 'Bayer AG',
#        'Deutsche Bank AG', 'Porsche AG', 'Merck KGaA'], dtype=object)

# %%
df.company.nunique()
# Out:
# 12

# %%
df.company.value_counts()
# Out:
# company
# Volkswagen AG          32
# Siemens AG             32
# Allianz SE             32
# BMW AG                 32
# BASF SE                32
# Deutsche Telekom AG    32
# Daimler AG             32
# SAP SE                 32
# Bayer AG               32
# Deutsche Bank AG       32
# Porsche AG             32
# Merck KGaA             32
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# company                      0
# period                       0
# revenue                      0
# net_income                   0
# liabilities                  0
# assets                       0
# equity                       0
# roa                          0
# roe                          0
# debt_to_equity               0
# percentage_debt_to_equity    0
# dtype: int64

# %% [markdown]
# ## 5.2. Period

# %%
df[['period']].sample(5)
# Out:
#          period
# 285   6/30/2024
# 363   9/30/2023
# 48   12/31/2021
# 356   9/30/2022
# 149   3/31/2021

# %%
df.period.dtype
# Out:
# dtype('O')

# %%
df.period.unique()
# Out:
# array(['12/31/2017', '12/31/2018', '12/31/2019', '12/31/2020',
#        '12/31/2021', '12/31/2022', '12/31/2023', '12/31/2024',
#        '3/31/2017', '3/31/2018', '3/31/2019', '3/31/2020', '3/31/2021',
#        '3/31/2022', '3/31/2023', '3/31/2024', '6/30/2017', '6/30/2018',
#        '6/30/2019', '6/30/2020', '6/30/2021', '6/30/2022', '6/30/2023',
#        '6/30/2024', '9/30/2017', '9/30/2018', '9/30/2019', '9/30/2020',
#        '9/30/2021', '9/30/2022', '9/30/2023', '9/30/2024'], dtype=object)

# %%
df.period.nunique()
# Out:
# 32

# %%
df.period.value_counts()
# Out:
# period
# 12/31/2017    12
# 12/31/2018    12
# 9/30/2023     12
# 9/30/2022     12
# 9/30/2021     12
# 9/30/2020     12
# 9/30/2019     12
# 9/30/2018     12
# 9/30/2017     12
# 6/30/2024     12
# 6/30/2023     12
# 6/30/2022     12
# 6/30/2021     12
# 6/30/2020     12
# 6/30/2019     12
# 6/30/2018     12
# 6/30/2017     12
# 3/31/2024     12
# 3/31/2023     12
# 3/31/2022     12
# 3/31/2021     12
# 3/31/2020     12
# 3/31/2019     12
# 3/31/2018     12
# 3/31/2017     12
# 12/31/2024    12
# 12/31/2023    12
# 12/31/2022    12
# 12/31/2021    12
# 12/31/2020    12
# 12/31/2019    12
# 9/30/2024     12
# Name: count, dtype: int64

# %%
df.period = pd.to_datetime(df.period, errors='coerce')

df.period
# Out:
# 0     2017-12-31
# 1     2017-12-31
# 2     2017-12-31
# 3     2017-12-31
# 4     2017-12-31
#          ...
# 379   2024-09-30
# 380   2024-09-30
# 381   2024-09-30
# 382   2024-09-30
# 383   2024-09-30
# Name: period, Length: 384, dtype: datetime64[ns]

# %%
df.period.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Durchgeführte Maßnahme</h3>
#   <ul>
#     <li>Die betreffende Spalte wurde in den Datentyp datetime konvertiert, um präzise zeitbasierte Analysen zu ermöglichen.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.3. Revenue

# %%
df[['revenue']].sample(5)
# Out:
#          revenue
# 91   16754700510
# 56   13009192330
# 153   8720665039
# 73    8282175431
# 136   9927936838

# %%
df.revenue.dtype
# Out:
# dtype('int64')

# %%
df.revenue.isnull().sum()
# Out:
# np.int64(0)

# %%
df[df.revenue < 0]  # Der Umsatz darf nicht negativ sein.
# Out:
# Empty DataFrame
# Columns: [company, period, revenue, net_income, liabilities, assets, equity, roa, roe, debt_to_equity, percentage_debt_to_equity]
# Index: []

# %% [markdown]
# ## 5.4. Net Income

# %%
df[['net_income']].sample(5)
# Out:
#        net_income
# 199  7.448730e+08
# 352  5.697617e+08
# 110  2.015330e+09
# 14   1.091045e+09
# 73   4.593908e+08

# %%
df.net_income.dtype
# Out:
# dtype('float64')

# %%
df.net_income.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 5.5. Liabilities

# %%
df[['liabilities']].sample(5)
# Out:
#      liabilities
# 57   33962234582
# 174  43343894473
# 319  48121419304
# 275  43413456694
# 22   35954156213

# %%
df.liabilities.dtype
# Out:
# dtype('int64')

# %%
df.liabilities.isna().sum()
# Out:
# np.int64(0)

# %%
df[df.liabilities < 0]  # Verbindlichkeiten dürfen nicht negativ sein.
# Out:
# Empty DataFrame
# Columns: [company, period, revenue, net_income, liabilities, assets, equity, roa, roe, debt_to_equity, percentage_debt_to_equity]
# Index: []

# %% [markdown]
# ## 5.6. Assets

# %%
df[['assets']].sample(5)
# Out:
#           assets
# 317  73302995160
# 184  60234434421
# 138  42728183777
# 25   55130546327
# 62   62464433746

# %%
df.assets.dtype
# Out:
# dtype('int64')

# %%
df.assets.isnull().sum()
# Out:
# np.int64(0)

# %%
df[(df.assets <= 0)]  # Das Gesamtvermögen muss größer als null sein.
# Out:
# Empty DataFrame
# Columns: [company, period, revenue, net_income, liabilities, assets, equity, roa, roe, debt_to_equity, percentage_debt_to_equity]
# Index: []

# %% [markdown]
# ## 5.7. Equity

# %%
df[['equity']].sample(5)
# Out:
#           equity
# 352  22956866781
# 376  17576276882
# 124  36122528684
# 123  48801871894
# 5    25261653663

# %%
df.equity.dtype
# Out:
# dtype('int64')

# %%
df.equity.isna().sum()
# Out:
# np.int64(0)

# %%
df[df.equity <= 0]  # Das Eigenkapital muss größer als null sein, um roe zuverlässig berechnen zu können.
# Out:
# Empty DataFrame
# Columns: [company, period, revenue, net_income, liabilities, assets, equity, roa, roe, debt_to_equity, percentage_debt_to_equity]
# Index: []

# %% [markdown]
# ## 5.8. Roa

# %%
df[['roa']].sample(5)
# Out:
#                roa
# 110    294.190.307
# 169  1.543.810.374
# 305  1.490.876.154
# 207  2.290.068.378
# 344    818.216.606

# %%
df.roa = (df.net_income / df.assets) * 100

df.roa
# Out:
# 0      0.942176
# 1      1.696389
# 2      2.299543
# 3      1.426140
# 4      2.641347
#          ...
# 379    1.147713
# 380    1.749565
# 381    3.603733
# 382    1.468014
# 383    2.866690
# Name: roa, Length: 384, dtype: float64

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Durchgeführte Maßnahme</h3>
#   <ul>
#     <li>Da die betreffende Spalte nicht die erwarteten Prozentwerte (%) enthielt, wurde sie unter Verwendung der vorhandenen Variablen im Datensatz neu berechnet und rekonstruiert.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.9. Roe

# %%
df[['roe']].sample(5)
# Out:
#                roe
# 161  1.052.068.959
# 151  1.733.691.877
# 281  1.107.885.775
# 238    244.813.252
# 247  1.519.179.847

# %%
df.roe = (df.net_income / df.equity) * 100

df.roe
# Out:
# 0       1.542628
# 1       4.219731
# 2       7.603361
# 3       3.005707
# 4       4.523561
#          ...
# 379     2.770148
# 380     3.928965
# 381    15.221112
# 382     2.562408
# 383     5.908478
# Name: roe, Length: 384, dtype: float64

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Durchgeführte Maßnahme</h3>
#   <ul>
#     <li>Da die betreffende Spalte nicht die erwarteten Prozentwerte (%) enthielt, wurde sie im Rahmen des Analyseprozesses aus den vorhandenen Variablen abgeleitet und neu erstellt.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.10. Debt to Equity

# %%
df[['debt_to_equity']].head()
# Out:
#   debt_to_equity
# 0    637.303.746
# 1  1.487.478.214
# 2  2.306.466.848
# 3  1.107.581.539
# 4     71.259.635

# %%
df.debt_to_equity = df.liabilities / df.equity

df.debt_to_equity
# Out:
# 0      0.637304
# 1      1.487478
# 2      2.306467
# 3      1.107582
# 4      0.712596
#          ...
# 379    1.413623
# 380    1.245681
# 381    3.223707
# 382    0.745492
# 383    1.061080
# Name: debt_to_equity, Length: 384, dtype: float64

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Durchgeführte Maßnahme</h3>
#   <ul>
#     <li>Aufgrund eines identifizierten Skalierungsproblems wurde die betreffende Verhältnisvariable unter Verwendung der zugrunde liegenden Finanzdaten neu berechnet.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.11. Percentage Debt to Equity

# %%
df[['debt_to_equity']] * 100
# Out:
#      debt_to_equity
# 0         63.730375
# 1        148.747821
# 2        230.646685
# 3        110.758154
# 4         71.259635
# ..              ...
# 379      141.362327
# 380      124.568075
# 381      322.370707
# 382       74.549229
# 383      106.108003
#
# [384 rows x 1 columns]

# %%
df[['percentage_debt_to_equity']]
# Out:
#     percentage_debt_to_equity
# 0                       0,00%
# 1                     283,68%
# 2                     329,65%
# 3                       0,00%
# 4                     634,80%
# ..                        ...
# 379                     0,00%
# 380                     0,00%
# 381                   472,16%
# 382                   343,72%
# 383                   556,84%
#
# [384 rows x 1 columns]

# %%
df.drop(columns='percentage_debt_to_equity', inplace=True)

df
# Out:
#               company     period      revenue    net_income  liabilities  \
# 0       Volkswagen AG 2017-12-31   9750496618  5.168898e+08  21354201295
# 1          Siemens AG 2017-12-31  19716237464  1.276840e+09  45009303223
# 2          Allianz SE 2017-12-31  19458831198  1.600107e+09  48538978480
# 3              BMW AG 2017-12-31  18808147150  9.601843e+08  35382107627
# 4             BASF SE 2017-12-31  16895580815  1.797082e+09  28309420014
# ..                ...        ...          ...           ...          ...
# 379            SAP SE 2024-09-30  10824151396  8.302800e+08  42369695133
# 380          Bayer AG 2024-09-30   9332023907  7.466675e+08  23673143006
# 381  Deutsche Bank AG 2024-09-30  18549946525  2.323022e+09  49199711543
# 382        Porsche AG 2024-09-30  15911174550  1.241694e+09  36125130235
# 383        Merck KGaA 2024-09-30  15036344926  1.704098e+09  30603212259
#
#           assets       equity       roa        roe  debt_to_equity
# ...

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Durchgeführte Maßnahme</h3>
#   <ul>
#     <li>Die betreffende Spalte wurde aufgrund einer festgestellten Berechnungsinkonsistenz aus dem Datensatz entfernt.</li>
#   </ul>
# </div>

# %% [markdown]
# # 6. Analiz ve Görselleştirme

# %%
df
# Out:
#               company     period      revenue    net_income  liabilities  \
# 0       Volkswagen AG 2017-12-31   9750496618  5.168898e+08  21354201295
# 1          Siemens AG 2017-12-31  19716237464  1.276840e+09  45009303223
# 2          Allianz SE 2017-12-31  19458831198  1.600107e+09  48538978480
# 3              BMW AG 2017-12-31  18808147150  9.601843e+08  35382107627
# 4             BASF SE 2017-12-31  16895580815  1.797082e+09  28309420014
# ..                ...        ...          ...           ...          ...
# 379            SAP SE 2024-09-30  10824151396  8.302800e+08  42369695133
# 380          Bayer AG 2024-09-30   9332023907  7.466675e+08  23673143006
# 381  Deutsche Bank AG 2024-09-30  18549946525  2.323022e+09  49199711543
# 382        Porsche AG 2024-09-30  15911174550  1.241694e+09  36125130235
# 383        Merck KGaA 2024-09-30  15036344926  1.704098e+09  30603212259
#
#           assets       equity       roa        roe  debt_to_equity
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company         384 non-null    object
#  1   period          384 non-null    datetime64[ns]
#  2   revenue         384 non-null    int64
#  3   net_income      384 non-null    float64
#  4   liabilities     384 non-null    int64
#  5   assets          384 non-null    int64
#  6   equity          384 non-null    int64
#  7   roa             384 non-null    float64
#  8   roe             384 non-null    float64
#  9   debt_to_equity  384 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(1)
# memory usage: 30.1+ KB

# %%
df[['revenue', 'net_income', 'liabilities', 'assets', 'equity', 'roa', 'roe', 'debt_to_equity']].describe().T
# Out:
#                 count          mean           std           min           25%  \
# revenue         384.0  1.270992e+10  4.095183e+09  5.149850e+09  9.315161e+09
# net_income      384.0  1.249025e+09  5.445441e+08  2.980309e+08  8.643813e+08
# liabilities     384.0  3.115579e+10  1.139538e+10  1.004637e+10  2.085174e+10
# assets          384.0  6.141624e+10  1.698922e+10  2.177324e+10  5.074013e+10
# equity          384.0  3.026045e+10  1.172803e+10  1.001762e+10  1.966813e+10
# roa             384.0  2.260345e+00  1.406047e+00  5.011021e-01  1.310458e+00
# roe             384.0  4.992758e+00  3.401370e+00  9.804799e-01  2.596827e+00
# debt_to_equity  384.0  1.235580e+00  7.815920e-01  2.196627e-01  7.320947e-01
#
#                          50%           75%           max
# revenue         1.266963e+10  1.621724e+10  1.990964e+10
# net_income      1.145476e+09  1.560234e+09  2.884007e+09
# liabilities     3.230659e+10  4.088942e+10  4.976940e+10
# ...

# %%
df.groupby('company')[['revenue']].mean().sort_values('revenue', ascending=False)
# Out:
#                           revenue
# company
# Merck KGaA           1.342963e+10
# BASF SE              1.320693e+10
# Allianz SE           1.301543e+10
# Daimler AG           1.298295e+10
# Deutsche Telekom AG  1.294884e+10
# BMW AG               1.279363e+10
# Siemens AG           1.266250e+10
# Deutsche Bank AG     1.255227e+10
# Volkswagen AG        1.242831e+10
# SAP SE               1.241668e+10
# Bayer AG             1.228015e+10
# Porsche AG           1.180174e+10

# %%
sns.barplot(data=df.groupby('company')['revenue'].mean().sort_values(ascending=False).reset_index(), x='revenue', y='company')

plt.xlabel('Durchschnittlicher Umsatz (EUR)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittlicher Umsatz nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['net_income']].mean().sort_values('net_income', ascending=False)
# Out:
#                        net_income
# company
# Merck KGaA           1.394800e+09
# Volkswagen AG        1.335629e+09
# BASF SE              1.322951e+09
# Allianz SE           1.314984e+09
# BMW AG               1.264378e+09
# Daimler AG           1.262170e+09
# Deutsche Bank AG     1.254326e+09
# Bayer AG             1.244583e+09
# Deutsche Telekom AG  1.242394e+09
# Porsche AG           1.128405e+09
# Siemens AG           1.123660e+09
# SAP SE               1.100021e+09

# %%
sns.barplot(data=df.groupby('company')['net_income'].mean().sort_values(ascending=False).reset_index(), x='net_income', y='company')

plt.xlabel('Durchschnittlicher Nettogewinn (EUR)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittlicher Nettogewinn nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['liabilities']].mean().sort_values('liabilities', ascending=False)
# Out:
#                       liabilities
# company
# Merck KGaA           3.421248e+10
# Daimler AG           3.311068e+10
# SAP SE               3.241681e+10
# Bayer AG             3.220732e+10
# Porsche AG           3.193370e+10
# Deutsche Bank AG     3.180432e+10
# BMW AG               3.164122e+10
# Siemens AG           3.035153e+10
# Allianz SE           2.992707e+10
# Deutsche Telekom AG  2.972130e+10
# BASF SE              2.894841e+10
# Volkswagen AG        2.759459e+10

# %%
sns.barplot(data=df.groupby('company')['liabilities'].mean().sort_values(ascending=False).reset_index(), x='liabilities', y='company')

plt.xlabel('Durchschnittliche Verbindlichkeiten (EUR)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittliche Verbindlichkeiten nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['assets']].mean().sort_values('assets', ascending=False)
# Out:
#                            assets
# company
# Deutsche Bank AG     6.448487e+10
# BASF SE              6.325328e+10
# Deutsche Telekom AG  6.296833e+10
# Porsche AG           6.290280e+10
# Merck KGaA           6.261155e+10
# BMW AG               6.254100e+10
# SAP SE               6.149468e+10
# Daimler AG           6.102514e+10
# Bayer AG             6.085879e+10
# Siemens AG           5.931568e+10
# Volkswagen AG        5.856722e+10
# Allianz SE           5.697155e+10

# %%
sns.barplot(data=df.groupby('company')['assets'].mean().sort_values(ascending=False).reset_index(), x='assets', y='company')

plt.xlabel('Durchschnittliches Vermögen (EUR)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittliches Vermögen nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['equity']].mean().sort_values('equity', ascending=False)
# Out:
#                            equity
# company
# BASF SE              3.430486e+10
# Deutsche Telekom AG  3.324702e+10
# Deutsche Bank AG     3.268055e+10
# Volkswagen AG        3.097263e+10
# Porsche AG           3.096910e+10
# BMW AG               3.089978e+10
# SAP SE               2.907786e+10
# Siemens AG           2.896415e+10
# Bayer AG             2.865147e+10
# Merck KGaA           2.839908e+10
# Daimler AG           2.791445e+10
# Allianz SE           2.704448e+10

# %%
sns.barplot(data=df.groupby('company')['equity'].mean().sort_values(ascending=False).reset_index(), x='equity', y='company')

plt.xlabel('Durchschnittliches Eigenkapital (EUR)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittliches Eigenkapital nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['roa']].mean().sort_values('roa', ascending=False)
# Out:
#                           roa
# company
# Volkswagen AG        2.676691
# Allianz SE           2.546871
# Bayer AG             2.371059
# Merck KGaA           2.368700
# BASF SE              2.354594
# BMW AG               2.229955
# Daimler AG           2.205607
# Deutsche Bank AG     2.104061
# Deutsche Telekom AG  2.103734
# Siemens AG           2.084857
# Porsche AG           2.062370
# SAP SE               2.015645

# %%
sns.barplot(data=df.groupby('company')['roa'].mean().sort_values(ascending=False).reset_index(), x='roa', y='company')

plt.xlabel('Durchschnittliche Gesamtkapitalrendite (%)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittliche Gesamtkapitalrendite nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['roe']].mean().sort_values('roe', ascending=False)
# Out:
#                           roe
# company
# Daimler AG           5.642682
# Volkswagen AG        5.631437
# Allianz SE           5.560286
# Merck KGaA           5.434668
# Bayer AG             5.391142
# BMW AG               4.947637
# SAP SE               4.815630
# Siemens AG           4.725762
# Deutsche Bank AG     4.559157
# Porsche AG           4.406742
# Deutsche Telekom AG  4.400859
# BASF SE              4.397099

# %%
sns.barplot(data=df.groupby('company')['roe'].mean().sort_values(ascending=False).reset_index(), x='roe', y='company')

plt.xlabel('Durchschnittliche Eigenkapitalrendite (%)')
plt.ylabel('Unternehmen')
plt.title('Durchschnittliche Eigenkapitalrendite nach Unternehmen')

plt.show()

# %%
df.groupby('company')[['debt_to_equity']].mean().sort_values('debt_to_equity', ascending=False)
# Out:
#                      debt_to_equity
# company
# Daimler AG                 1.513517
# Merck KGaA                 1.443471
# Bayer AG                   1.366722
# SAP SE                     1.332244
# BMW AG                     1.262382
# Siemens AG                 1.257575
# Allianz SE                 1.243841
# Porsche AG                 1.169503
# Deutsche Bank AG           1.132813
# Deutsche Telekom AG        1.068697
# Volkswagen AG              1.059909
# BASF SE                    0.976288

# %%
sns.barplot(data=df.groupby('company')['debt_to_equity'].mean().sort_values(ascending=False).reset_index(), x='debt_to_equity', y='company')

plt.xlabel('Durchschnittlicher Verschuldungsgrad')
plt.ylabel('Unternehmen')
plt.title('Durchschnittlicher Verschuldungsgrad nach Unternehmen')

plt.show()

# %%
fig, ax = plt.subplots(4, 2, figsize=(14, 18))

sns.barplot(data=df.groupby('company')['revenue'].mean().sort_values(ascending=False).reset_index(), x='revenue', y='company', ax=ax[0, 0])

ax[0, 0].set_title('Durchschnittlicher Umsatz nach Unternehmen')
ax[0, 0].set_xlabel('Durchschnittlicher Umsatz (EUR)')
ax[0, 0].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['net_income'].mean().sort_values(ascending=False).reset_index(), x='net_income', y='company', ax=ax[0, 1])

ax[0, 1].set_title('Durchschnittlicher Nettogewinn nach Unternehmen')
ax[0, 1].set_xlabel('Durchschnittlicher Nettogewinn (EUR)')
ax[0, 1].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['liabilities'].mean().sort_values(ascending=False).reset_index(), x='liabilities', y='company', ax=ax[1, 0])

ax[1, 0].set_title('Durchschnittliche Verbindlichkeiten nach Unternehmen')
ax[1, 0].set_xlabel('Durchschnittliche Verbindlichkeiten (EUR)')
ax[1, 0].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['assets'].mean().sort_values(ascending=False).reset_index(), x='assets', y='company', ax=ax[1, 1])

ax[1, 1].set_title('Durchschnittliches Gesamtvermögen nach Unternehmen')
ax[1, 1].set_xlabel('Durchschnittliches Gesamtvermögen (EUR)')
ax[1, 1].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['equity'].mean().sort_values(ascending=False).reset_index(), x='equity', y='company', ax=ax[2, 0])

ax[2, 0].set_title('Durchschnittliches Eigenkapital nach Unternehmen')
ax[2, 0].set_xlabel('Durchschnittliches Eigenkapital (EUR)')
ax[2, 0].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['roa'].mean().sort_values(ascending=False).reset_index(), x='roa', y='company', ax=ax[2, 1])

ax[2, 1].set_title('Durchschnittliche Gesamtkapitalrendite nach Unternehmen')
ax[2, 1].set_xlabel('Durchschnittliche Gesamtkapitalrendite (%)')
ax[2, 1].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['roe'].mean().sort_values(ascending=False).reset_index(), x='roe', y='company', ax=ax[3, 0])

ax[3, 0].set_title('Durchschnittliche Eigenkapitalrendite nach Unternehmen')
ax[3, 0].set_xlabel('Durchschnittliche Eigenkapitalrendite (%)')
ax[3, 0].set_ylabel('Unternehmen')

sns.barplot(data=df.groupby('company')['debt_to_equity'].mean().sort_values(ascending=False).reset_index(), x='debt_to_equity', y='company', ax=ax[3, 1])

ax[3, 1].set_title('Durchschnittlicher Verschuldungsgrad nach Unternehmen')
ax[3, 1].set_xlabel('Durchschnittlicher Verschuldungsgrad')
ax[3, 1].set_ylabel('Unternehmen')

fig.suptitle('Finanzkennzahlen auf Unternehmensebene', fontsize=16, fontweight='bold', y=1)
plt.tight_layout()

plt.show()

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #2e7d32; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1b5e20;'>📊 Ergebnisse 1 – Unternehmensbezogene Bewertung auf Basis durchschnittlicher Finanzkennzahlen</h3>
#   <ul>
#     <li><strong>Merck KGaA</strong> belegt beim durchschnittlichen Umsatz und Nettogewinn den ersten Platz und nimmt damit hinsichtlich der finanziellen Größe eine führende Position ein. Die hohe Verschuldungsquote deutet jedoch auf einen ausgeprägten Leverage-Effekt hin.</li>
#     <li><strong>BASF SE</strong> zeichnet sich durch eine starke Eigenkapitalstruktur aus und gehört in Bezug auf Vermögen und Umsatz zur Spitzengruppe. Die vergleichsweise niedrigere Verschuldungsquote spricht für eine höhere Bilanzstabilität.</li>
#     <li><strong>Allianz SE</strong> gehört bei Umsatz und Nettogewinn zur oberen Gruppe und weist eine starke Roa-Performance auf. Das Verschuldungsniveau ist jedoch moderat erhöht.</li>
#     <li><strong>Daimler AG</strong> führt beim durchschnittlichen Roe, was auf eine hohe Eigenkapitaleffizienz hinweist. Gleichzeitig deutet die führende Position bei der Verschuldungsquote darauf hin, dass der hohe Roe durch Leverage unterstützt sein könnte.</li>
#     <li><strong>Volkswagen AG</strong> führt beim Roa und zeigt damit eine effiziente Nutzung der Vermögenswerte. Die Verschuldungsquote bleibt vergleichsweise moderat.</li>
#     <li><strong>BMW AG</strong> befindet sich beim Roe und Nettogewinn in der oberen Gruppe und zeigt eine insgesamt ausgewogene Finanzstruktur.</li>
#     <li><strong>Siemens AG</strong> ist bei den durchschnittlichen Kennzahlen im oberen Mittelfeld positioniert und weist kein extremes Risikoprofil auf Basis der Finanzkennzahlen auf.</li>
#     <li><strong>SAP SE</strong> liegt beim Nettogewinn und Roe im Mittelfeld und verfügt über ein moderates Verschuldungsniveau.</li>
#     <li><strong>Bayer AG</strong> zeigt eine starke Roa-Performance, jedoch wirft die hohe Verschuldungsquote Fragen hinsichtlich des finanziellen Risikos auf.</li>
#     <li><strong>Deutsche Bank AG</strong> nimmt beim Vermögensvolumen eine führende Position ein, gehört jedoch bei Roa oder Roe nicht zur Spitzengruppe. Die bilanzielle Struktur ist im Kontext des Bankensektors zu bewerten.</li>
#     <li><strong>Deutsche Telekom AG</strong> zählt bei Vermögen und Eigenkapital zur oberen Gruppe und weist eine moderate Roa-Performance auf.</li>
#     <li><strong>Porsche AG</strong> befindet sich bei den durchschnittlichen Kennzahlen im unteren Mittelfeld und zeigt keine übermäßige Nutzung von Leverage.</li>
#     <li><strong>Gesamtbewertung:</strong> Die Analyse der durchschnittlichen Finanzkennzahlen zeigt, dass eine größere Bilanzsumme nicht zwangsläufig mit höherer Effizienz einhergeht. Insbesondere die Beziehung zwischen Roe und Verschuldungsquote verdeutlicht, dass Leverage bei einigen Unternehmen eine entscheidende Rolle für die Renditeentwicklung spielt.</li>
#   </ul>
# </div>

# %%
sns.relplot(
    data=df.assign(year=df['period'].dt.year),
    x='year',
    y='revenue',
    col='company',
    col_wrap=6,
    kind='line',
    height=4,
    facet_kws={'sharey': False}
           )

plt.tight_layout()

plt.show()

# %%
sns.relplot(
    data=df.assign(year=df['period'].dt.year),
    x='year',
    y='net_income',
    col='company',
    col_wrap=6,
    kind='line',
    height=4,
    facet_kws={'sharey': False}
           )

plt.tight_layout()

plt.show()

# %%
sns.relplot(
    data=df.assign(year=df['period'].dt.year),
    x='year',
    y='debt_to_equity',
    col='company',
    col_wrap=6,
    kind='line',
    height=4,
    facet_kws={'sharey': False}
           )

plt.tight_layout()

plt.show()

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #2e7d32; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1b5e20;'>📊 Ergebnisse 2 – Unternehmensbezogene Bewertung auf Basis der Trendanalyse</h3>
#   <ul>
#     <li><strong>Volkswagen AG</strong> verzeichnete im Jahr 2020 einen Rückgang bei Umsatz und Nettogewinn, gefolgt von einer Erholung in den darauffolgenden Jahren. Der Verschuldungsgrad zeigt insgesamt eine rückläufige Tendenz, was auf eine Erholung nach der Pandemie in Kombination mit einer vorsichtigen Finanzstruktur hindeutet.</li>
#     <li><strong>Siemens AG</strong> weist Schwankungen bei Umsatz und Nettogewinn auf, zeigt jedoch insgesamt eine moderate Aufwärtstendenz. Obwohl der Verschuldungsgrad periodische Ausschläge enthält, ist kein nicht nachhaltiger Anstieg zu beobachten.</li>
#     <li><strong>Allianz SE</strong> zeigte insbesondere nach 2022 eine starke Entwicklung bei Umsatz und Nettogewinn. Allerdings ist eine deutliche Volatilität im Verschuldungsgrad zu erkennen, was darauf hindeutet, dass die Performance mit periodischen Risikophasen einherging.</li>
#     <li><strong>BMW AG</strong> zeigt einen kontinuierlichen Aufwärtstrend bei Umsatz und Nettogewinn. Der Verschuldungsgrad scheint unter Kontrolle zu sein, wodurch das Unternehmen zu den ausgewogen wachsenden Unternehmen zählt.</li>
#     <li><strong>BASF SE</strong> weist ein schwankendes Muster bei Umsatz und Nettogewinn auf, mit Anzeichen einer Erholung nach 2022. Der Verschuldungsgrad zeigt keinen übermäßigen Anstieg und spiegelt ein moderates Risikoprofil wider.</li>
#     <li><strong>Deutsche Telekom AG</strong> bleibt beim Umsatz relativ stabil, während der Nettogewinn periodische Schwankungen zeigt. Der Verschuldungsgrad weist eine steigende Tendenz auf, was auf eine zunehmende finanzielle Hebelwirkung hindeutet.</li>
#     <li><strong>Daimler AG</strong> zeigt eine hohe Volatilität sowohl beim Nettogewinn als auch beim Verschuldungsgrad. Der deutliche Anstieg des Verschuldungsgrades im Zeitraum 2021–2023 legt nahe, dass die Performance durch Leverage unterstützt worden sein könnte. Das Risikoniveau erscheint relativ hoch.</li>
#     <li><strong>SAP SE</strong> verzeichnete im Jahr 2022 einen starken Anstieg des Nettogewinns, gefolgt von einem Rückgang. Der Verschuldungsgrad zeigt ähnliche Schwankungen, was auf eine begrenzte Stabilität der Performance hinweist.</li>
#     <li><strong>Bayer AG</strong> zeigt eine rückläufige Tendenz beim Nettogewinn, während im Jahr 2023 ein deutlicher Anstieg des Verschuldungsgrades zu beobachten war. Diese Kombination wirft Fragen hinsichtlich des finanziellen Risikos auf.</li>
#     <li><strong>Deutsche Bank AG</strong> erreichte im Jahr 2020 einen Tiefpunkt und zeigte anschließend eine starke Erholung beim Nettogewinn. Obwohl der Verschuldungsgrad volatil bleibt, ist die strukturell hohe Hebelwirkung des Bankensektors zu berücksichtigen.</li>
#     <li><strong>Porsche AG</strong> weist insgesamt einen Aufwärtstrend bei Umsatz und Nettogewinn auf. Der Verschuldungsgrad ist nicht übermäßig volatil und deutet auf eine vergleichsweise ausgewogene Performance-Struktur hin.</li>
#     <li><strong>Merck KGaA</strong> zeigt nach 2022 eine starke Dynamik bei Umsatz und Nettogewinn. Obwohl der Verschuldungsgrad im Jahr 2023 anstieg, ging er 2024 wieder zurück, was auf ein performancegetriebenes Momentum-Profil hindeutet.</li>
#     <li><strong>Gesamtbewertung:</strong> Die Trendanalyse zeigt, dass sich Performance-Richtung und Risikodynamik unabhängig von der durchschnittlichen Unternehmensgröße unterscheiden. Insbesondere Anstiege des Verschuldungsgrades spielen eine zentrale Rolle bei der Bewertung der Nachhaltigkeit von Phasen hoher Profitabilität.</li>
#   </ul>
# </div>
